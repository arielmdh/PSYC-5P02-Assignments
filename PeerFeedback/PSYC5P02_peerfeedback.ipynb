# %%
from psychopy.tools.filetools import fromFile
# I wasn't sure what they are importing here, when I looked it up the "Fromfile" functions seems to be for importing various files, I'm not sure if this is necessary

# %%
#I like the way they decided to add the input fields, I used "expInfo" instead but I like the "addField" code, it lays out the process a little clearser
expName = 'VisualSearch'
dlg = gui.Dlg()
dlg.addField('SubjectID:')
dlg.addField('Trials Per Cond:')
ok_data = dlg.show()
if not dlg.OK:
    core.quit()

# %%
#For this section, I used the "thisExp" function to save my files, I think this way is more concise than the way I did it
sub_ID = ok_data[0]
trials = int(dlg.data[1])
fileName = sub_ID + "_" + expName
dataFile = open(fileName + '.csv', 'w')

# %%
# I think this part is well done, I don't think I could fully figure out how to get all of this information to come out of the data correctly so I appreciate their inclusion of all of the condition parameters
dataFile.write('SetSize,TP, RT, Correct, Missed\n')

# %%
# For this section, I think potentially it would be better to code the stimuli as actually the letters "T" and "L" so that you don't have to have the image saved to run the experiment
conditions = [5, 8, 12]
stim_size = 30
T = visual.ImageStim(win, 'Stimuli/T.png', size=stim_size) 
L = visual.ImageStim(win, 'Stimuli/L.png', size=stim_size)

# %%
 orin = random.choice(orientations)
# I almost did mine like this too with sampling randomly from a list. I ended up finding a solution in random.choice that didn't need to use a list but I think the list works well also but maybe not as truly "random"

# %%
if key == 'a':
                resp = 'a'
                break
            elif key == 'd':
                resp = 'd'
                break
            elif key == 'escape':
                core.quit()
# I think this set up for the keyboard response is better than mine. I think I tried to do mine similar to this but ended up doing something more complicated. I like how concise it is. 
# They also utilized get.Keys instead of wait.Keys, which is also more concise

# %%
#I think their feedback section could have been streamlined slighly.
# I used a true/false set up which made coding my feedback section easier as I could essentially just say true = "correct", false = "incorrect" whereas they have to go through each possible key response and it's accuracy

# %%
# I like that they added an additional instruction after the practice trials, I think it makes the transition into the real trials more clear

# %%
 if rt != 999:
            rt_list.append(rt)
            miss_rt = 0
            corr_list.append(corr)
        else:
            miss_rt_list.append(1)
            miss_rt = 1
            corr_list.append(0)

# I think this code is super interesting and not something I thought of at all.
# The if reaction time part is a cool way to keep track of missing responses

# %%
#Overall, I think this person has a strong understanding of how to code experiments, there are some things in their code that could be improved by making things more concise or not hard-coding the stimuli, however, they did things that I didn't think of and couldn't figure out.
